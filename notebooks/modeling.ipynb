# %% [markdown]
# ## importing libraries for models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso, SGDRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/processed/clean_flight_data.csv")

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Base line Model

# %%
lr= LinearRegression()

lr.fit(x_train, y_train['price'])
lr_pred = lr.predict(x_val)
r2 = r2_score(y_val, lr_pred)

print(f" the R2 score for the Baseline model is {r2}")
# Out:
#  the R2 score for the Baseline model is 0.9076144993079247

# %% [markdown]
# # Model Building

# %% [markdown]
# # Model- (1 to 7) and Comparison of model performances

# %%
models = {
    "LinearRegression": LinearRegression(),
    "SGDRegress": SGDRegressor(random_state=42),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "KNN": KNeighborsRegressor(),
    "DecisionTree": DecisionTreeRegressor(random_state=42),
    "RandomForest": RandomForestRegressor(random_state=42),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "AdaBoost": AdaBoostRegressor(random_state=42),

    "XGBoost": XGBRegressor(n_jobs=-1),



}


results = {}

for name, model in models.items():
    # pipe = make_pipeline(model)
    model.fit(x_train, y_train['price'])
    y_pred = model.predict(x_val)
    mae = mean_absolute_error(y_val, y_pred)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)
    results[name] = {'MAE': mae, 'RMSE': rmse, 'R2': r2}
    print(f"{name} ---> MAE = {mae:.2f}, RMSE = {rmse:.2f}, R2 = {r2:.3f}")
# Out:
# LinearRegression ---> MAE = 4667.59, RMSE = 6904.08, R2 = 0.908
# SGDRegress ---> MAE = 4679.90, RMSE = 6904.53, R2 = 0.908
# Ridge ---> MAE = 4667.68, RMSE = 6904.08, R2 = 0.908
# Lasso ---> MAE = 4666.48, RMSE = 6904.58, R2 = 0.908
# KNN ---> MAE = 4237.49, RMSE = 7165.54, R2 = 0.900
# DecisionTree ---> MAE = 2262.05, RMSE = 4870.32, R2 = 0.954
# RandomForest ---> MAE = 2019.84, RMSE = 3828.05, R2 = 0.972
# GradientBoosting ---> MAE = 3105.56, RMSE = 5160.92, R2 = 0.948
# AdaBoost ---> MAE = 4390.70, RMSE = 6532.79, R2 = 0.917
# XGBoost ---> MAE = 2371.16, RMSE = 4084.76, R2 = 0.968

# %% [markdown]
# 📌 **Observation** - from the above results, it is apparent the the best three models are RandomForest, XGBoost and DecisionTree

# %% [markdown]
# # Hyperparameter Tuning of top 3 models

# %%
from sklearn.model_selection import GridSearchCV

# %%
# rf= RandomForestRegressor(n_jobs=-1,random_state=42)



# params = {
#     'max_depth': [None,10,20],
#     'n_estimators': [300,400,500],
#     'min_samples_split': [2, 5,6],

# }

# grid = GridSearchCV(rf, param_grid=params, cv=3,scoring='r2', n_jobs=-1)
# grid.fit(x_train, y_train.values.ravel())

# print("Best parameter:", grid.best_params_, grid.best_score_)

# %%
# XGBoost= XGBRegressor(n_jobs=-1)

# params = {

#     'learning_rate': [0.05, 0.1,.2],
#     'max_depth': [9,10,12],
#     'n_estimators': [ 200,300,400,500],
# }

# grid = GridSearchCV(XGBoost, param_grid=params, cv=5,scoring='r2', n_jobs=-1)
# grid.fit(x_train, y_train)

# print("Best parameter:", grid.best_params_, grid.best_score_)

# %%
# DecisionTree= DecisionTreeRegressor(random_state=42)


# params = {
#     'max_depth': [None, 5, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4],

# }

# grid = GridSearchCV(DecisionTree, param_grid=params, cv=5)
# grid.fit(x_train, y_train)

# print("Best parameter:", grid.best_params_,grid.best_score_)
