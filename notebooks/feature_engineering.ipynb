# %% [markdown]
# # Let us create meaningful features from the data

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..")))

from src.config import CLEAN_FILGHT_DATA, FLIGHT_DATA

import pandas as pd

df = pd.read_csv(FLIGHT_DATA)
